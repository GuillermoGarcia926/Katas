# %%
#Ejercicio uno

primer_planeta = 149597870
segundo_planeta = 778547200

distancia = segundo_planeta - primer_planeta
print(distancia)

distancia2 = distancia * 0.621
print(distancia2)
# Out:
# 628949330
# 390577533.93

# %%
#Ejercicio 2

primer_planeta1 = input('149597870')
segundo_planeta2= input('778547200')

primer_planeta1 = int(primer_planeta)
segundo_planeta2 = int(segundo_planeta)

distancias = segundo_planeta2 - primer_planeta1
print(distancias)

distanciass = distancias * 0.621
print(abs(distanciass))
# Out:
# 628949330
# 390577533.93

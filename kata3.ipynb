# %%
Vel_Asteroide = 45
Cerca_sol = 25

if Vel_Asteroide > Cerca_sol:
    print("Se acerca un asteroide a maxima velocidad!!!")
else: 
    print("El asteroide no representa un peligro")

Metric_Asteroide = 20
asteroide = 19

if asteroide >= Metric_Asteroide:
    print("Oberseva el cielo y busca un asteroide") 
else:
    print("No hay ninguna amenaza a la vista")

velocidad1 = 25
tamaño2 = 120

if velocidad1 > 25 and tamaño2 >= 25:
    print("Se acerca un asteroide!!!")
elif velocidad1 >= 20:
    print("Observa el cielo, hay un asteroide!")
elif tamaño2 < 25:
    print("El asteroide no representa un peligro")
# Out:
# Se acerca un asteroide a maxima velocidad!!!
# No hay ninguna amenaza a la vista
# Observa el cielo, hay un asteroide!
